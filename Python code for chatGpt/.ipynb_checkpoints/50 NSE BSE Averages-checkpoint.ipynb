# %%
#### update companymaster file - check ipo listing from chittorgarh 

### run report designer in spider and save xls for bse, nse and sme

#### get marketcap from screener and save in marketcap from screener csv

#### run 57 Tradingview WL for percent change and new highs - this reads the file from tradingview
#### for 3 percent changes or more and new highs and makes a 0_tradingview_wl_yymmdd

#### run 50 nse bse averages - this takes nse/bse/sme averages and creates a combined average file (input file)

### run 51 combined nse bse files --- combines nse and bse files for a specific date - this combined file is used for 
#### report generation  -- this generates top 50 by value/volume for non-fno, fno and sme
#### this also creates non_fno_wl_yymmdd
#### this creates sme yymmdd 

#### run 56 delivery comparision over 2 days - this generates scrips where dely volumes are 3x of previous day
#### this generates 0_volume_3x_wl_yymmdd

#### run 53 report for multiple scrips
#### this takes 0_tradingview_wl_yymmdd (created in 57) and generate 7-day delivery report
#### this takes 0_volume_3x_wl_yymmdd (created in 56) and generate 7-day delivery report
#### this takes 0_non_fno_wl_yymmdd (created in 51) and generate 7-day delivery report
#### this takes sme yymmdd (created in 51) and generate 7-day delivery report
#### this also reads consolidated holdings file, create 0 my_holdings and generate 7-day delivery report

# %%
### this program reads the nse averages, bse averages, sme averages in spider/user/report folder 
### and combines them (after removing tags for trade to trade/ sm-st / z group etc)
### and writes to nse bse averages in input folder under sql stock market data

### nse bse averages is used by 53 multiple scrips to read averages and print them

# %%
### lenovo desktop file path
master_file_path = "C:\\Users\\User\\Dropbox\\SQL Stock Market Data\\Python Code from ChatGPT\\Master File\\CompanyMaster.csv"
directory = "C:\\Users\\User\\Dropbox\\SQL Stock Market Data\\Data Files\\"  # Replace with the path to your directory
output_path = "C:\\Users\\User\\Dropbox\\SQL Stock Market Data\\Python Code from ChatGPT\\Output File\\"
combined_file_path = "C:\\Users\\User\\Dropbox\\SQL Stock Market Data\\Delivery Price Combined Files\\"

column_order = ['NSE_Code','BSE_Code','Date','NSE_Delivery','BSE_Delivery']

# %%
#### Lenovo laptop file path


spider_path = "C:\\Spider\\User\\Report\\"

master_file_path = "C:\\Users\\sarda\\Dropbox\\SQL Stock Market Data\\Python Code from ChatGPT\\Master File\\CompanyMaster.csv"
directory = "C:\\Users\\sarda\\Dropbox\\SQL Stock Market Data\\Data Files\\"  # Replace with the path to your directory
output_path = "C:\\Users\\sarda\\Dropbox\\SQL Stock Market Data\\Python Code from ChatGPT\\Output File\\"
input_path = "C:\\Users\\sarda\\Dropbox\\SQL Stock Market Data\\Python Code from ChatGPT\\Input File\\"
combined_file_path = "C:\\Users\\sarda\\Dropbox\\SQL Stock Market Data\\Delivery Price Combined Files\\"

# Define the new column order
column_order = ["Exchange", "Code", "Name", "Close", "ema5", "ema10", "ema20", "ema50", "ema200", "75d high", "75d low"]

# Define the corresponding column types
column_types = {"Close": float, "ema5": float, "ema10": float, "ema20": float, "ema50": float, "ema200": float, 
                "75d high": float, "75d low": float}

columns_to_fill = ["Close", "ema5", "ema10", "ema20", "ema50", "ema200", "75d high", "75d low"]

# %%
nse_avg = spider_path + "NSE Averages.xls"
sme_avg = spider_path + "SME Averages.xls"
bse_avg = spider_path + "BSE Averages.xls"

input_file = input_path + "ShortListed Stocks.xlsx"

bse_sheet = "BSE Averages"
nse_sheet = "NSE Averages"

# %%
import os
import csv
import pandas as pd

# %%
nse_avg_df = pd.read_excel(nse_avg, names=column_order, dtype=column_types)
sme_avg_df = pd.read_excel(sme_avg, names=column_order, dtype=column_types)
bse_avg_df = pd.read_excel(bse_avg, names=column_order, dtype=column_types)
#input_file_df = pd.read_excel(input_file)


nse_avg_df[columns_to_fill] = nse_avg_df[columns_to_fill].fillna(0)
bse_avg_df[columns_to_fill] = bse_avg_df[columns_to_fill].fillna(0)
sme_avg_df[columns_to_fill] = sme_avg_df[columns_to_fill].fillna(0)

nse_sme_avg_df = pd.concat([nse_avg_df,sme_avg_df], ignore_index = True)

nse_avg_df = nse_sme_avg_df

# %%
#nse_avg_df.info()

# %%
nse_avg_df['Name'] = nse_avg_df['Name'].str.replace('_T$',"",regex=True)
nse_avg_df['Name'] = nse_avg_df['Name'].str.replace('_Z$',"",regex=True)
nse_avg_df['Name'] = nse_avg_df['Name'].str.replace(' SM$',"",regex=True)
nse_avg_df['Name'] = nse_avg_df['Name'].str.replace(' ST$',"",regex=True)


nse_avg_df['Name'] = nse_avg_df['Name'].str.strip()
nse_avg_df['Code'] = nse_avg_df['Code'].astype(str)

bse_avg_df['Code'] = bse_avg_df['Code'].astype(str)

# %%
# Assuming nse_avg_df and bse_avg_df are your DataFrames

# Replace 'NSE BSE Averages.xlsx' with the desired output file path
averages_file = input_path + 'NSE BSE Averages.xlsx'

# Use ExcelWriter to write to a new Excel file with two sheets
with pd.ExcelWriter(averages_file, engine='openpyxl', mode='w') as writer:
    nse_avg_df.to_excel(writer, sheet_name='NSE Averages', index=False)
    bse_avg_df.to_excel(writer, sheet_name='BSE Averages', index=False)

# Confirm the write operation
print(f"Data has been written to '{averages_file}' under the sheets 'NSE Averages' and 'BSE Averages'.")
# Out:
# Data has been written to 'C:\Users\sarda\Dropbox\SQL Stock Market Data\Python Code from ChatGPT\Input File\NSE BSE Averages.xlsx' under the sheets 'NSE Averages' and 'BSE Averages'.

# %%
# code_0.ipynb

import nbformat
from nbconvert.preprocessors import ExecutePreprocessor

# Load "56 Delivery comparision over 2 days.ipynb"
with open('56 Delivery comparision over 2 days.ipynb', 'r') as f:
    nb_content = nbformat.read(f, as_version=4)

# Execute the notebook
exec_preprocessor = ExecutePreprocessor(timeout=600, kernel_name='python3')
exec_preprocessor.preprocess(nb_content, {'metadata': {'path': './'}})

# Extract variables or functions from the executed notebook
executed_code = '\n'.join(cell['source'] for cell in nb_content.cells if cell.cell_type == 'code')

# Execute the extracted code in the current notebook
exec(executed_code)
# Out:
# ['combined_231207.csv', 'combined_231206.csv']
# 231207
#                               Delivery comparision over 2 days, value over 500, ratio over 3x  231207
#                               ______________________________________________________________________
#
#
# Company Name                       Symbol            Dely        PrevDely    Price    PrevPrice    Ratio   Change
# ==============================     ================================================================================
#
# LKP Finance Ltd.                   LKPMERFIN        897,023       5,468      165.60      158.65    164.05    Up
# Vertoz Advertising Ltd.            VERTOZ           300,699      14,238      394.65      343.40     21.12    Up
# Dredging Corporation Of India      DREDGECORP       727,454      44,958      562.70      513.45     16.18    Up
# Sandur Manganese & Iron Ores L     504918            32,959       2,069    1,873.60    1,633.60     15.93    Up
# ITI Ltd.                           ITI            3,603,985     261,180      300.10      271.45     13.80    Up
#
# Cosmic CRF Ltd.                    543928           207,200      17,600      371.70      309.75     11.77    Up
# Finolex Industries Ltd.            FINPIPE        4,212,252     388,623      214.45      206.10     10.84    Up
# IVP Ltd.                           IVP              250,390      23,967      249.75      219.50     10.45    Up
# Advait Infratech Ltd.              543230            88,483      10,014      626.55      532.45      8.84    Up
# Shiva Cement Ltd.                  532323         1,127,554     133,898       58.20       51.66      8.42    Up
#
# Precision Wires India Ltd.         PRECWIRE       1,595,035     195,807      127.25      115.75      8.15    Up
# Ircon International Ltd.           IRCON         26,244,494   3,291,236      160.75      171.95      7.97    Down
# Bharti Airtel Ltd.                 BHARTIARTL    22,751,688   2,859,307    1,000.00    1,024.45      7.96    Down
# Sanghi Industries Ltd.             SANGHIIND      3,029,089     386,121      131.50      135.70      7.84    Down
# Sundram Fasteners Ltd.             SUNDRMFAST       239,147      32,113    1,249.50    1,260.50      7.45    Down
#
# Speciality Restaurants Ltd.        SPECIALITY       367,544      50,470      184.70      184.35      7.28    Up
# One97 Communications Ltd.          PAYTM         20,596,041   2,874,964      661.35      813.05      7.16    Down
# IDFC First Bank Ltd.               IDFCFIRSTB   165,676,651  23,141,748       87.70       90.40      7.16    Down
# India Tourism Development Corp     ITDC             171,693      24,090      450.10      428.00      7.13    Up
# Aditya Birla Capital Ltd.          ABCAPITAL      6,801,851   1,004,907      166.60      173.05      6.77    Down
#
# Housing & Urban Development Co     HUDCO         23,768,640   3,559,055       92.30       86.80      6.68    Up
# Sansera Engineering Ltd.           SANSERA          306,110      46,978      927.70      891.70      6.52    Up
# PC Jeweller Ltd.                   PCJEWELLER     8,631,886   1,334,234       30.25       28.10      6.47    Up
# IKIO Lighting Ltd.                 IKIO             767,397     121,215      341.40      338.65      6.33    Up
# Brightcom Group Ltd.               BCG           47,636,054   7,889,187       20.05       16.80      6.04    Up
#
# SpiceJet Ltd.                      500285        18,703,712   3,229,724       52.29       43.58      5.79    Up
# IRB Infrastructure Developers      IRB           32,806,850   5,717,789       38.45       37.25      5.74    Up
# Tasty Bite Eatables Ltd.           TASTYBITE          4,211         744   14,317.10   14,621.90      5.66    Down
# Atul Ltd.                          ATUL              92,590      16,385    6,875.90    6,830.70      5.65    Up
# MMTC Ltd.                          MMTC           9,943,081   1,788,857       55.75       50.70      5.56    Up
#
# Salzer Electronics Ltd.            SALZERELEC       291,552      53,426      404.85      388.15      5.46    Up
# Emami Ltd.                         EMAMILTD         946,538     178,873      501.20      500.50      5.29    Up
# KIOCL Ltd.                         KIOCL            492,557      93,171      342.15      311.05      5.29    Up
# Hercules Hoists Ltd.               HERCULES         143,108      27,236      368.10      360.40      5.25    Up
# Chaman Lal Setia Exports Ltd.      CLSEL            269,595      51,868      240.00      230.70      5.20    Up
#
# AVT Natural Products Ltd.          AVTNPL         1,018,241     198,026       94.85       89.55      5.14    Up
# Ritco Logistics Ltd.               RITCO            233,072      45,551      287.00      255.30      5.12    Up
# BEML Land Assets Ltd.              BLAL             309,952      61,199      165.30      160.30      5.06    Up
# Vishnu Prakash                     VPRPL          1,694,068     334,831      204.60      201.75      5.06    Up
# Spacenet Enterprises India Ltd     SPCENET        2,931,923     583,042       27.70       24.95      5.03    Up
#
# Maharashtra Scooters Ltd.          MAHSCOOTER        11,410       2,383    8,353.80    8,071.80      4.79    Up
# Sterling and Wilson Renewable      SWSOLAR        3,256,334     698,187      407.40      388.25      4.66    Up
# Star Health and Allied Insuran     STARHEALTH     2,551,952     560,868      571.75      558.15      4.55    Up
# GMR Airports Infrastructure Lt     GMRINFRA      14,535,695   3,281,124       61.70       61.35      4.43    Up
# Knowledge Marine & Engineering     543273            43,375       9,875    1,663.95    1,402.85      4.39    Up
#
# HCL Infosystems Ltd.               HCL-INSYS      2,863,953     664,963       18.45       17.30      4.31    Up
# Jyoti Structures Ltd.              JYOTISTRUC     8,383,626   1,987,750       19.00       18.65      4.22    Up
# Sagar Cements Ltd.                 SAGCEM           323,350      76,911      269.85      268.10      4.20    Up
# Godrej Industries Ltd.             GODREJIND        474,871     113,332      667.95      653.90      4.19    Up
# Kajaria Ceramics Ltd.              KAJARIACER       157,830      37,763    1,378.40    1,384.10      4.18    Down
#
# Sanghvi Movers Ltd.                SANGHVIMOV       182,588      44,013      847.65      808.80      4.15    Up
# PG Electroplast Ltd.               PGEL              33,736       8,325    2,242.65    2,293.75      4.05    Down
# Axiscades Technologies Ltd.        AXISCADES        259,119      63,974      618.75      562.50      4.05    Up
# Alembic Ltd.                       ALEMBICLTD     3,608,507     908,423       92.30       85.20      3.97    Up
# Carborundum Universal Ltd.         CARBORUNIV       126,927      32,551    1,207.95    1,182.55      3.90    Up
#
# Tube Investments of India Ltd.     TIINDIA        2,371,068     635,657    3,412.60    3,334.25      3.73    Up
# Reliance Industrial Infrastruc     RIIL             626,816     171,054    1,186.05    1,116.60      3.66    Up
# Hemisphere Properties India Lt     HEMIPROP       1,198,734     332,704      141.10      136.45      3.60    Up
# Aptus Value Housing Finance In     APTUS            467,607     130,448      298.60      299.70      3.58    Down
# Himatsingka Seide Ltd.             HIMATSEIDE     1,192,563     332,771      182.95      171.20      3.58    Up
#
# Greenply Industries Ltd.           GREENPLY         410,526     114,908      198.85      197.50      3.57    Up
# Royal Orchid Hotels Ltd.           ROHLTD           216,826      60,738      347.20      321.15      3.57    Up
# The State Trading Corporation      STCINDIA         604,985     170,264      132.80      129.50      3.55    Up
# RR Kabel                           RRKABEL          276,355      79,139    1,689.25    1,668.40      3.49    Up
# Arvind Ltd.                        ARVIND         1,041,849     298,920      227.75      223.95      3.49    Up
#
# HFCL Ltd.                          HFCL          10,092,646   2,900,217       70.35       66.45      3.48    Up
# Praj Industries Ltd.               PRAJIND        1,511,676     435,170      607.50      639.90      3.47    Down
# Avantel Ltd.                       532406           791,244     228,882      123.60      126.80      3.46    Down
# IDBI Bank Ltd.                     IDBI          11,595,002   3,386,790       67.10       64.10      3.42    Up
# Shipping Corporation Of India      SCI            4,324,868   1,265,382      159.00      155.70      3.42    Up
#
# HP Adhesives Ltd.                  HPAL             489,614     144,765      103.55      100.40      3.38    Up
# LIC Housing Finance Ltd.           LICHSGFIN      1,934,019     573,977      518.70      505.15      3.37    Up
# Visaka Industries Ltd.             VISAKAIND      1,086,990     324,474       92.90       88.60      3.35    Up
# Astral Ltd.                        ASTRAL           651,521     196,337    1,969.60    1,966.35      3.32    Up
# Delta Corp Ltd.                    DELTACORP      6,462,630   1,971,185      139.75      138.90      3.28    Up
#
# Venus Remedies Ltd.                VENUSREM         135,379      41,516      397.15      384.20      3.26    Up
# Vedant Fashions Ltd.               MANYAVAR         556,263     171,642    1,457.65    1,438.50      3.24    Up
# Patel Engineering Ltd.             PATELENG      13,796,238   4,258,111       56.60       54.10      3.24    Up
# Home First Finance Company Ind     HOMEFIRST        415,864     128,363    1,025.55      951.20      3.24    Up
# Sumitomo Chemical India Ltd.       SUMICHEM         352,259     110,591      415.00      412.65      3.19    Up
#
# SJVN Ltd.                          SJVN          23,383,436   7,379,916       90.90       84.45      3.17    Up
# Mangalore Refinery And Petroch     MRPL           3,347,302   1,059,060      129.90      125.40      3.16    Up
# Indus Towers Ltd.                  INDUSTOWER     4,350,121   1,377,512      193.80      185.70      3.16    Up
# MSTC Ltd.                          MSTCLTD          442,919     141,075      444.75      431.05      3.14    Up
# KBC Global Ltd.                    KBCGLOBAL     28,199,448   9,004,434        1.95        1.95      3.13    No Change
#
# The Ugar Sugar Works Ltd.          UGARSUGAR        970,012     313,147       84.40       87.80      3.10    Down
# Poonawalla Fincorp Ltd.            POONAWALLA     2,323,220     757,864      421.35      410.80      3.07    Up
# Utkarsh Small Finance Bank Ltd     UTKARSHBNK     3,608,011   1,179,405       51.60       50.10      3.06    Up
# Inox Wind Energy Ltd.              IWEL              36,793      12,182    4,246.80    4,116.75      3.02    Up
#    ScripCode                    Company Name    Price      Dely  DelyRatio
# 3     504918  Sandur Manganese & Iron Ores L  1873.60     32959  15.929918
# 5     543928                 Cosmic CRF Ltd.   371.70    207200  11.772727
# 8     543230           Advait Infratech Ltd.   626.55     88483   8.835930
# 9     532323               Shiva Cement Ltd.    58.20   1127554   8.420992
# 25    500285                   SpiceJet Ltd.    52.29  18703712   5.791118
# 44    543273  Knowledge Marine & Engineering  1663.95     43375   4.392405
# 67    532406                    Avantel Ltd.   123.60    791244   3.456995
